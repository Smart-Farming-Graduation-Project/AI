# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/"
# Out:
#  archive.zip	        Untitled	  Untitled1.ipynb   Untitled4.ipynb
# 'Copy of Task2.ipynb'   Untitled0.ipynb   Untitled2.ipynb   Untitled5.ipynb
#  Task2.ipynb	       'Untitled (1)'	  Untitled3.ipynb   Untitled6.ipynb

# %%
import zipfile

zip_path = "/content/drive/My Drive/Colab Notebooks/archive.zip"
extract_path = "/content/"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Extraction complete!")
# Out:
# Extraction complete!

# %%
# !nvidia-smi
# Out:
# Mon Feb 17 16:01:12 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8             13W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device Name:", torch.cuda.get_device_name(0))
else:
    print("No GPU found")
# Out:
# CUDA Available: True
# Device Name: Tesla T4

# %%
# !pip install ultralytics

# %%
# !pip install --upgrade ultralytics

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")  # Load YOLO11 model

# %%
model.train(
    data="/content/data.yaml",
    epochs=10,
    batch=16,
    imgsz=640
)
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !ls runs/detect/
# Out:
# ls: cannot access 'runs/detect/': No such file or directory

# %%
# !ls runs/detect/train*/weights/
# Out:
# runs/detect/train/weights/:
#
# runs/detect/train2/weights/:
#
# runs/detect/train3/weights/:
# best.pt  last.pt

# %%
# !cp runs/detect/train3/weights/best.pt "/content/drive/My Drive/best_10epochs_yolo11.pt"

# %%
# now i will rerun the model with 20 epochs but i will use the weights from the previous 10-Epoch model to speed it up

model = YOLO("/content/drive/My Drive/best_10epochs_yolo11.pt")

# trian for 20 epochs

model.train(data="/content/data.yaml", epochs=20, batch=16, imgsz=640)
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp runs/detect/train4/weights/best.pt "/content/drive/My Drive/best_20epochs_yolo11.pt"

# %%
from google.colab import files

files.download("/content/drive/My Drive/best_10epochs_yolo11.pt")

# %%
from google.colab import files

files.download("/content/drive/My Drive/best_20epochs_yolo11.pt")

# %%
# !ls /content/
# Out:
# README.dataset.txt   data.yaml	runs	     test   valid
# README.roboflow.txt  drive	sample_data  train  yolo11n.pt

# %%
# !ls runs/detect/
# Out:
# train  train2  train3  train4

# %%
# !zip -r /content/yolo_results.zip runs/detect/
# Out:
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/train/ (stored 0%)
#   adding: runs/detect/train/weights/ (stored 0%)
#   adding: runs/detect/train/args.yaml (deflated 52%)
#   adding: runs/detect/train4/ (stored 0%)
#   adding: runs/detect/train4/labels_correlogram.jpg (deflated 35%)
#   adding: runs/detect/train4/train_batch5652.jpg (deflated 10%)
#   adding: runs/detect/train4/val_batch0_pred.jpg (deflated 6%)
#   adding: runs/detect/train4/R_curve.png (deflated 8%)
#   adding: runs/detect/train4/val_batch2_labels.jpg (deflated 6%)
#   adding: runs/detect/train4/results.csv (deflated 61%)
#   adding: runs/detect/train4/events.out.tfevents.1739721598.eb1a6228abcb.8384.1 (deflated 93%)
#   adding: runs/detect/train4/val_batch0_labels.jpg (deflated 6%)
#   adding: runs/detect/train4/val_batch1_pred.jpg (deflated 7%)
#   adding: runs/detect/train4/train_batch0.jpg (deflated 1%)
#   adding: runs/detect/train4/PR_curve.png (deflated 13%)
# ...

# %%
# !ls /content/
# Out:
# README.dataset.txt   data.yaml	runs	     test   valid	yolo_results.zip
# README.roboflow.txt  drive	sample_data  train  yolo11n.pt

# %%
# !cp /content/yolo_results.zip "/content/drive/My Drive/yolo_results.zip"

# %%
# now i will try 50 epochs
# Load the best model from 20 epochs
model = YOLO("/content/drive/My Drive/best_20epochs_yolo11.pt")

# Train for 50 more epochs (continuing from the 20-epoch model)
model.train(data="/content/data.yaml", epochs=50, batch=16, imgsz=640)
# Out:
# Ultralytics 8.3.75 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
