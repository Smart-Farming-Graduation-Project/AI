# %%
# !nvidia-smi
# Out:
# Thu Feb  6 19:26:37 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## Decompress Data

# %%
# %cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !ls
# Out:
#  archive.zip  'Colab Notebooks'   Resume.pdf  'Task 1.zip'  'Task 2.zip'  'Task 3.zip'

# %%
# !unzip archive.zip -d /content/Data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Data/train/labels/collage_1_jpg.rf.b48aa1e8ee399fbb0ce90253183bf746.txt
#   inflating: /content/Data/train/labels/collage_1_jpg.rf.c0b213ccf1d5ae19cdea6af2cd65ee0c.txt
#   inflating: /content/Data/train/labels/collage_201_jpg.rf.495e880e4a1a0786aabc3ae0391f6083.txt
#   inflating: /content/Data/train/labels/collage_201_jpg.rf.78631ea7ce3a595900e2585dde36e28a.txt
#   inflating: /content/Data/train/labels/collage_201_jpg.rf.a80e101387b6acf533dc318ea1edf9eb.txt
#   inflating: /content/Data/train/labels/collage_202_jpg.rf.0c996ddf7552c801e0fa0458d60e5c28.txt
#   inflating: /content/Data/train/labels/collage_202_jpg.rf.6a449dc538c9969afed8c6066d4826d9.txt
#   inflating: /content/Data/train/labels/collage_202_jpg.rf.751868eae3d12c9874921cfa5410f27c.txt
#   inflating: /content/Data/train/labels/collage_203_jpg.rf.3fafc6a6c77754ace551ebbbc022636f.txt
# ...

# %%
# %cd /content/
# Out:
# /content

# %% [markdown]
# ## install ultralytics for Yolo

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.8/914.8 kB 61.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 38.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !mv ./Data/data.yaml ./

# %%
# !yolo task=detect mode=train model='yolov5n.pt' data=data.yaml epochs=50 batch=64 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 5.31M/5.31M [00:00<00:00, 348MB/s]
# Ultralytics 8.3.72 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
