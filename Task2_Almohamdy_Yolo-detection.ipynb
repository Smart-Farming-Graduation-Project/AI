# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /kaggle/working

# %%
# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5933.9/8062.4 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://t3.ftcdn.net/jpg/06/04/54/70/240_F_604547093_FmuK2VH2Gq5zoXzeJkygDsejsUxXZaOg.jpg' save=True
# Out:
# /kaggle/working
# ...
# 100%|███████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 117MB/s]
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100%|██████████████████████████████████████| 39.0k/39.0k [00:00<00:00, 5.59MB/s]
# image 1/1 /kaggle/working/240_F_604547093_FmuK2VH2Gq5zoXzeJkygDsejsUxXZaOg.jpg: 352x640 1 bird, 1 cat, 4 dogs, 84.4ms
# Speed: 10.4ms preprocess, 84.4ms inference, 243.9ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /kaggle/working
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100%|████████████████████████████████████████| 104k/104k [00:00<00:00, 50.1MB/s]
# image 1/1 /kaggle/working/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 52.5ms
# Speed: 3.7ms preprocess, 52.5ms inference, 147.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# without Detect
Image(filename='/kaggle/working/dog.jpeg', height=600)

# %%
# After Detection
Image(filename='/kaggle/working/runs/detect/predict2/dog.jpeg', height=600)

# %%
# without Detect
Image(filename='/kaggle/working/240_F_604547093_FmuK2VH2Gq5zoXzeJkygDsejsUxXZaOg.jpg', height=600)

# %%
# After Detection
Image(filename='/kaggle/working/runs/detect/predict/240_F_604547093_FmuK2VH2Gq5zoXzeJkygDsejsUxXZaOg.jpg', height=600)

# %% [markdown]
# # يوجع القطط

# %%
model = YOLO('/kaggle/working/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /kaggle/working/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 56.0ms
# Speed: 4.6ms preprocess, 56.0ms inference, 153.8ms postprocess per image at shape (1, 3, 640, 384)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data='/kaggle/input/ymal-file/data.yaml' epochs=25 imgsz=800 plots=True
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# ...
# 100%|███████████████████████████████████████| 21.5M/21.5M [00:00<00:00, 254MB/s]
# New https://pypi.org/project/ultralytics/8.3.17 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train3/
# Out:
# F1_curve.png					   train_batch1.jpg
# PR_curve.png					   train_batch120.jpg
# P_curve.png					   train_batch121.jpg
# R_curve.png					   train_batch122.jpg
# args.yaml					   train_batch2.jpg
# confusion_matrix.png				   val_batch0_labels.jpg
# confusion_matrix_normalized.png			   val_batch0_pred.jpg
# events.out.tfevents.1729288289.9330936d08d8.282.0  val_batch1_labels.jpg
# labels.jpg					   val_batch1_pred.jpg
# labels_correlogram.jpg				   val_batch2_labels.jpg
# results.csv					   val_batch2_pred.jpg
# results.png					   weights
# train_batch0.jpg

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/confusion_matrix.png', width=600)
# Out:
# /kaggle/working

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/results.png', width=600)
# Out:
# /kaggle/working

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/val_batch0_pred.jpg', width=600)
# Out:
# /kaggle/working

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train3/weights/best.pt data='/kaggle/input/ymal-file/data.yaml'
# Out:
# /kaggle/working
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /kaggle/input/apple-data/Data/valid/labels... 103 images, 0 backgr
# val: WARNING ⚠️ Cache directory /kaggle/input/apple-data/Data/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        103        201      0.756      0.542       0.62      0.455
# Speed: 2.5ms preprocess, 7.1ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train3/weights/best.pt conf=0.25 source='/kaggle/input/apple-data/Data/test/images' save=True
# Out:
# /kaggle/working
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/5 /kaggle/input/apple-data/Data/test/images/apple--106-_jpg.rf.5d4cdc6f5bd48667c045a43a5fb3d970.jpg: 544x800 5 D Apples, 52.8ms
# image 2/5 /kaggle/input/apple-data/Data/test/images/apple--119-_jpg.rf.d7b946189406fa5cb1f936ba2edcfa11.jpg: 416x800 2 D Apples, 39.2ms
# image 3/5 /kaggle/input/apple-data/Data/test/images/apple--132-_jpg.rf.b38cfb540837f6de31bee356952362ca.jpg: 608x800 2 D Apples, 39.3ms
# image 4/5 /kaggle/input/apple-data/Data/test/images/apple--178-_jpg.rf.4ca4da2d5e684cd9636f0987633bcf31.jpg: 576x800 1 D Apple, 38.9ms
# image 5/5 /kaggle/input/apple-data/Data/test/images/apple--179-_jpg.rf.d2a7634cf17537da52c08c32c1fb0172.jpg: 800x544 3 D Apples, 39.2ms
# Speed: 3.5ms preprocess, 41.9ms inference, 34.4ms postprocess per image at shape (1, 3, 800, 544)
# ...

# %%
import glob
from IPython.display import Image, display

base_path = '/kaggle/working/runs/detect/'

subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:5]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("-"*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
